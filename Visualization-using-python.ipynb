# %% [markdown]
# <a href="https://colab.research.google.com/github/Farrukh077/Big-data-analysis/blob/main/Visualization-using-python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = 'customer.csv'
df = pd.read_csv(file_path)

# %%
category_counts = df['Customer_Segment'].value_counts()

# %%
plt.figure(figsize=(8, 8))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%')
plt.axis('equal')
plt.title('Customer Category Distribution')
plt.show()

# %%
category_counts = df['Province'].value_counts()

# %%
plt.figure(figsize=(8, 8))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%')
plt.axis('equal')
plt.title('Provinces')
plt.show()

# %%
category_counts = df['Region'].value_counts()

# %%
plt.figure(figsize=(8, 8))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%')
plt.axis('equal')
plt.title('Regions')
plt.show()
